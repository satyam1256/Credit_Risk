# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support
import warnings
import os

# %%
# Load the dataset
a1 = pd.read_excel("../data/Unseen_Dataset.xlsx")

# %%
df = a1.copy()

# %%
df.head()
# Out:
#    pct_tl_open_L6M  pct_tl_closed_L6M  Tot_TL_closed_L12M  pct_tl_closed_L12M  \
# 0            0.000                0.0                   0               0.000
# 1            0.000                0.0                   0               0.000
# 2            0.125                0.0                   0               0.000
# 3            0.000                0.0                   0               0.000
# 4            0.000                0.0                   1               0.167
#
#    Tot_Missed_Pmnt  CC_TL  Home_TL  PL_TL  Secured_TL  Unsecured_TL  ...  \
# 0                0      0        0      4           1             4  ...
# 1                0      0        0      0           0             1  ...
# 2                1      0        0      0           2             6  ...
# 3                0      0        0      0           3             0  ...
# 4                0      0        0      0           6             0  ...
#
#    PL_Flag  pct_PL_enq_L6m_of_ever  pct_CC_enq_L6m_of_ever  HL_Flag  GL_Flag  \
# 0        1                   0.000                     0.0        1        0
# 1        0                   0.000                     0.0        0        0
# 2        0                   0.000                     0.0        1        0
# 3        0                   0.000                     0.0        0        0
# 4        0                   0.429                     0.0        1        0
#
#    MARITALSTATUS      EDUCATION  GENDER  last_prod_enq2  first_prod_enq2
# 0        Married           12TH       M              PL               PL
# 1         Single       GRADUATE       F    ConsumerLoan     ConsumerLoan
# 2        Married            SSC       M    ConsumerLoan           others
# 3        Married  POST-GRADUATE       M              AL               AL
# 4        Married           12TH       M    ConsumerLoan               PL
#
# [5 rows x 42 columns]

# %%
columns_to_be_removed = []

for i in df.columns:
    if df.loc[df[i] == -99999].shape[0] > 10000:
        columns_to_be_removed .append(i)

# %%
columns_to_be_removed
# Out:
# []

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        print(i)
# Out:
# MARITALSTATUS
# EDUCATION
# GENDER
# last_prod_enq2
# first_prod_enq2

# %%
numeric_columns = []
for i in df.columns:
    if df[i].dtype != 'object' and i not in ['PROSPECTID']:
        numeric_columns.append(i)

# %%
numeric_columns
# Out:
# ['pct_tl_open_L6M',
#  'pct_tl_closed_L6M',
#  'Tot_TL_closed_L12M',
#  'pct_tl_closed_L12M',
#  'Tot_Missed_Pmnt',
#  'CC_TL',
#  'Home_TL',
#  'PL_TL',
#  'Secured_TL',
#  'Unsecured_TL',
#  'Other_TL',
#  'Age_Oldest_TL',
#  'Age_Newest_TL',
#  'time_since_recent_payment',
#  'max_recent_level_of_deliq',
#  'num_deliq_6_12mts',
#  'num_times_60p_dpd',
#  'num_std_12mts',
#  'num_sub',
#  'num_sub_6mts',
#  'num_sub_12mts',
#  'num_dbt',
#  'num_dbt_12mts',
#  'num_lss',
#  'recent_level_of_deliq',
#  'CC_enq_L12m',
#  'PL_enq_L12m',
#  'time_since_recent_enq',
#  'enq_L3m',
#  'NETMONTHLYINCOME',
#  'Time_With_Curr_Empr',
#  'CC_Flag',
#  'PL_Flag',
#  'pct_PL_enq_L6m_of_ever',
#  'pct_CC_enq_L6m_of_ever',
#  'HL_Flag',
#  'GL_Flag']

# %%
df.loc[df['EDUCATION'] == 'SSC',['EDUCATION']]              = 1
df.loc[df['EDUCATION'] == '12TH',['EDUCATION']]             = 2
df.loc[df['EDUCATION'] == 'GRADUATE',['EDUCATION']]         = 3
df.loc[df['EDUCATION'] == 'UNDER GRADUATE',['EDUCATION']]   = 3
df.loc[df['EDUCATION'] == 'POST-GRADUATE',['EDUCATION']]    = 4
df.loc[df['EDUCATION'] == 'OTHERS',['EDUCATION']]           = 1
df.loc[df['EDUCATION'] == 'PROFESSIONAL',['EDUCATION']]     = 3

# %%
df['EDUCATION'].value_counts()
df['EDUCATION'] = df['EDUCATION'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pct_tl_open_L6M            100 non-null    float64
#  1   pct_tl_closed_L6M          100 non-null    float64
#  2   Tot_TL_closed_L12M         100 non-null    int64
#  3   pct_tl_closed_L12M         100 non-null    float64
#  4   Tot_Missed_Pmnt            100 non-null    int64
#  5   CC_TL                      100 non-null    int64
#  6   Home_TL                    100 non-null    int64
#  7   PL_TL                      100 non-null    int64
#  8   Secured_TL                 100 non-null    int64
#  9   Unsecured_TL               100 non-null    int64
#  10  Other_TL                   100 non-null    int64
#  11  Age_Oldest_TL              100 non-null    int64
#  12  Age_Newest_TL              100 non-null    int64
#  13  time_since_recent_payment  100 non-null    int64
#  14  max_recent_level_of_deliq  100 non-null    int64
#  15  num_deliq_6_12mts          100 non-null    int64
#  16  num_times_60p_dpd          100 non-null    int64
#  17  num_std_12mts              100 non-null    int64
#  18  num_sub                    100 non-null    int64
#  19  num_sub_6mts               100 non-null    int64
#  20  num_sub_12mts              100 non-null    int64
#  21  num_dbt                    100 non-null    int64
#  22  num_dbt_12mts              100 non-null    int64
#  23  num_lss                    100 non-null    int64
#  24  recent_level_of_deliq      100 non-null    int64
#  25  CC_enq_L12m                100 non-null    int64
#  26  PL_enq_L12m                100 non-null    int64
#  27  time_since_recent_enq      100 non-null    int64
#  28  enq_L3m                    100 non-null    int64
#  29  NETMONTHLYINCOME           100 non-null    int64
#  30  Time_With_Curr_Empr        100 non-null    int64
#  31  CC_Flag                    100 non-null    int64
#  32  PL_Flag                    100 non-null    int64
#  33  pct_PL_enq_L6m_of_ever     100 non-null    float64
#  34  pct_CC_enq_L6m_of_ever     100 non-null    float64
#  35  HL_Flag                    100 non-null    int64
#  36  GL_Flag                    100 non-null    int64
#  37  MARITALSTATUS              100 non-null    object
#  38  EDUCATION                  100 non-null    int64
#  39  GENDER                     100 non-null    object
#  40  last_prod_enq2             100 non-null    object
#  41  first_prod_enq2            100 non-null    object
# dtypes: float64(5), int64(33), object(4)
# memory usage: 32.9+ KB

# %%
df_encoded = pd.get_dummies(df, columns=['MARITALSTATUS','GENDER', 'last_prod_enq2' ,'first_prod_enq2'])

df_encoded.info()
k = df_encoded.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pct_tl_open_L6M               100 non-null    float64
#  1   pct_tl_closed_L6M             100 non-null    float64
#  2   Tot_TL_closed_L12M            100 non-null    int64
#  3   pct_tl_closed_L12M            100 non-null    float64
#  4   Tot_Missed_Pmnt               100 non-null    int64
#  5   CC_TL                         100 non-null    int64
#  6   Home_TL                       100 non-null    int64
#  7   PL_TL                         100 non-null    int64
#  8   Secured_TL                    100 non-null    int64
#  9   Unsecured_TL                  100 non-null    int64
#  10  Other_TL                      100 non-null    int64
#  11  Age_Oldest_TL                 100 non-null    int64
#  12  Age_Newest_TL                 100 non-null    int64
#  13  time_since_recent_payment     100 non-null    int64
#  14  max_recent_level_of_deliq     100 non-null    int64
#  15  num_deliq_6_12mts             100 non-null    int64
#  16  num_times_60p_dpd             100 non-null    int64
#  17  num_std_12mts                 100 non-null    int64
#  18  num_sub                       100 non-null    int64
#  19  num_sub_6mts                  100 non-null    int64
#  20  num_sub_12mts                 100 non-null    int64
#  21  num_dbt                       100 non-null    int64
#  22  num_dbt_12mts                 100 non-null    int64
#  23  num_lss                       100 non-null    int64
#  24  recent_level_of_deliq         100 non-null    int64
#  25  CC_enq_L12m                   100 non-null    int64
#  26  PL_enq_L12m                   100 non-null    int64
#  27  time_since_recent_enq         100 non-null    int64
#  28  enq_L3m                       100 non-null    int64
#  29  NETMONTHLYINCOME              100 non-null    int64
#  30  Time_With_Curr_Empr           100 non-null    int64
#  31  CC_Flag                       100 non-null    int64
#  32  PL_Flag                       100 non-null    int64
#  33  pct_PL_enq_L6m_of_ever        100 non-null    float64
#  34  pct_CC_enq_L6m_of_ever        100 non-null    float64
#  35  HL_Flag                       100 non-null    int64
#  36  GL_Flag                       100 non-null    int64
#  37  EDUCATION                     100 non-null    int64
#  38  MARITALSTATUS_Married         100 non-null    bool
#  39  MARITALSTATUS_Single          100 non-null    bool
#  40  GENDER_F                      100 non-null    bool
#  41  GENDER_M                      100 non-null    bool
#  42  last_prod_enq2_AL             100 non-null    bool
#  43  last_prod_enq2_CC             100 non-null    bool
#  44  last_prod_enq2_ConsumerLoan   100 non-null    bool
#  45  last_prod_enq2_HL             100 non-null    bool
#  46  last_prod_enq2_PL             100 non-null    bool
#  47  last_prod_enq2_others         100 non-null    bool
#  48  first_prod_enq2_AL            100 non-null    bool
#  49  first_prod_enq2_CC            100 non-null    bool
#  50  first_prod_enq2_ConsumerLoan  100 non-null    bool
#  51  first_prod_enq2_HL            100 non-null    bool
#  52  first_prod_enq2_PL            100 non-null    bool
#  53  first_prod_enq2_others        100 non-null    bool
# dtypes: bool(16), float64(5), int64(33)
# memory usage: 31.4 KB

# %%
df_encoded.head(10)
# Out:
#    pct_tl_open_L6M  pct_tl_closed_L6M  Tot_TL_closed_L12M  pct_tl_closed_L12M  \
# 0            0.000                0.0                   0               0.000
# 1            0.000                0.0                   0               0.000
# 2            0.125                0.0                   0               0.000
# 3            0.000                0.0                   0               0.000
# 4            0.000                0.0                   1               0.167
# 5            0.000                0.0                   2               0.333
# 6            0.000                0.0                   0               0.000
# 7            0.143                0.0                   1               0.143
# 8            0.000                0.0                   0               0.000
# 9            0.500                0.0                   1               0.500
#
#    Tot_Missed_Pmnt  CC_TL  Home_TL  PL_TL  Secured_TL  Unsecured_TL  ...  \
# 0                0      0        0      4           1             4  ...
# 1                0      0        0      0           0             1  ...
# 2                1      0        0      0           2             6  ...
# 3                0      0        0      0           3             0  ...
# 4                0      0        0      0           6             0  ...
# 5                0      0        0      0           6             0  ...
# 6                0      0        0      0           1             0  ...
# 7                0      1        0      2           2             5  ...
# 8                0      0        0      0           2             0  ...
# 9                0      0        0      0           0             2  ...
#
#    last_prod_enq2_ConsumerLoan  last_prod_enq2_HL  last_prod_enq2_PL  \
# 0                        False              False               True
# 1                         True              False              False
# 2                         True              False              False
# 3                        False              False              False
# 4                         True              False              False
# 5                         True              False              False
# 6                         True              False              False
# 7                        False              False              False
# 8                         True              False              False
# 9                         True              False              False
#
#    last_prod_enq2_others  first_prod_enq2_AL  first_prod_enq2_CC  \
# 0                  False               False               False
# 1                  False               False               False
# 2                  False               False               False
# 3                  False                True               False
# 4                  False               False               False
# 5                  False               False               False
# 6                  False               False               False
# 7                  False               False               False
# 8                  False               False               False
# 9                  False               False               False
#
#    first_prod_enq2_ConsumerLoan  first_prod_enq2_HL  first_prod_enq2_PL  \
# 0                         False               False                True
# 1                          True               False               False
# 2                         False               False               False
# 3                         False               False               False
# 4                         False               False                True
# 5                         False               False               False
# 6                         False               False               False
# 7                         False               False               False
# 8                         False               False               False
# 9                          True               False               False
#
#    first_prod_enq2_others
# 0                   False
# 1                   False
# 2                    True
# 3                   False
# 4                   False
# 5                    True
# 6                    True
# 7                    True
# 8                    True
# 9                   False
#
# [10 rows x 54 columns]

# %%
import pickle as pkl


model = pkl.load(open('model.pkl', 'rb'))

# %%
xtrain = df_encoded[50:60]

# %%
df_encoded["Target_result"] = model.predict(df_encoded)

# %%
df_encoded.head(10)
# Out:
#    pct_tl_open_L6M  pct_tl_closed_L6M  Tot_TL_closed_L12M  pct_tl_closed_L12M  \
# 0            0.000                0.0                   0               0.000
# 1            0.000                0.0                   0               0.000
# 2            0.125                0.0                   0               0.000
# 3            0.000                0.0                   0               0.000
# 4            0.000                0.0                   1               0.167
# 5            0.000                0.0                   2               0.333
# 6            0.000                0.0                   0               0.000
# 7            0.143                0.0                   1               0.143
# 8            0.000                0.0                   0               0.000
# 9            0.500                0.0                   1               0.500
#
#    Tot_Missed_Pmnt  CC_TL  Home_TL  PL_TL  Secured_TL  Unsecured_TL  ...  \
# 0                0      0        0      4           1             4  ...
# 1                0      0        0      0           0             1  ...
# 2                1      0        0      0           2             6  ...
# 3                0      0        0      0           3             0  ...
# 4                0      0        0      0           6             0  ...
# 5                0      0        0      0           6             0  ...
# 6                0      0        0      0           1             0  ...
# 7                0      1        0      2           2             5  ...
# 8                0      0        0      0           2             0  ...
# 9                0      0        0      0           0             2  ...
#
#    last_prod_enq2_HL  last_prod_enq2_PL  last_prod_enq2_others  \
# 0              False               True                  False
# 1              False              False                  False
# 2              False              False                  False
# 3              False              False                  False
# 4              False              False                  False
# 5              False              False                  False
# 6              False              False                  False
# 7              False              False                  False
# 8              False              False                  False
# 9              False              False                  False
#
#    first_prod_enq2_AL  first_prod_enq2_CC  first_prod_enq2_ConsumerLoan  \
# 0               False               False                         False
# 1               False               False                          True
# 2               False               False                         False
# 3                True               False                         False
# 4               False               False                         False
# 5               False               False                         False
# 6               False               False                         False
# 7               False               False                         False
# 8               False               False                         False
# 9               False               False                          True
#
#    first_prod_enq2_HL  first_prod_enq2_PL  first_prod_enq2_others  \
# 0               False                True                   False
# 1               False               False                   False
# 2               False               False                    True
# 3               False               False                   False
# 4               False                True                   False
# 5               False               False                    True
# 6               False               False                    True
# 7               False               False                    True
# 8               False               False                    True
# 9               False               False                   False
#
#    Target_result
# 0              0
# 1              1
# 2              0
# 3              0
# 4              1
# 5              1
# 6              1
# 7              0
# 8              1
# 9              0
#
# [10 rows x 55 columns]

# %%
df_encoded.columns
# Out:
# Index(['pct_tl_open_L6M', 'pct_tl_closed_L6M', 'Tot_TL_closed_L12M',
#        'pct_tl_closed_L12M', 'Tot_Missed_Pmnt', 'CC_TL', 'Home_TL', 'PL_TL',
#        'Secured_TL', 'Unsecured_TL', 'Other_TL', 'Age_Oldest_TL',
#        'Age_Newest_TL', 'time_since_recent_payment',
#        'max_recent_level_of_deliq', 'num_deliq_6_12mts', 'num_times_60p_dpd',
#        'num_std_12mts', 'num_sub', 'num_sub_6mts', 'num_sub_12mts', 'num_dbt',
#        'num_dbt_12mts', 'num_lss', 'recent_level_of_deliq', 'CC_enq_L12m',
#        'PL_enq_L12m', 'time_since_recent_enq', 'enq_L3m', 'NETMONTHLYINCOME',
#        'Time_With_Curr_Empr', 'CC_Flag', 'PL_Flag', 'pct_PL_enq_L6m_of_ever',
#        'pct_CC_enq_L6m_of_ever', 'HL_Flag', 'GL_Flag', 'EDUCATION',
#        'MARITALSTATUS_Married', 'MARITALSTATUS_Single', 'GENDER_F', 'GENDER_M',
#        'last_prod_enq2_AL', 'last_prod_enq2_CC', 'last_prod_enq2_ConsumerLoan',
#        'last_prod_enq2_HL', 'last_prod_enq2_PL', 'last_prod_enq2_others',
#        'first_prod_enq2_AL', 'first_prod_enq2_CC',
#        'first_prod_enq2_ConsumerLoan', 'first_prod_enq2_HL',
#        'first_prod_enq2_PL', 'first_prod_enq2_others', 'Target_result'],
#       dtype='object')

# %%
df_encoded["propensity_bckt"] = []

for i in df_encoded["Target_result"]:
    if i == 0:
        df_encoded["propensity_bckt"].append("P1")
    elif i==1:
        df_encoded["propensity_bckt"].append("P2")
    elif i==2:
        df_encoded["propensity_bckt"].append("P3")
    else:
        df_encoded["propensity_bckt"].append("P4")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df_encoded["propensity_bckt"] = []
#       3 for i in df_encoded["Target_result"]:
#       4     if i == 0:
#
# File c:\Users\Satyam\Desktop\CreditCardRiskModelling\Credit_project\satyam\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\Users\Satyam\Desktop\CreditCardRiskModelling\Credit_project\satyam\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\Satyam\Desktop\CreditCardRiskModelling\Credit_project\satyam\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File c:\Users\Satyam\Desktop\CreditCardRiskModelling\Credit_project\satyam\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (0) does not match length of index (100)

# %%
file_name = "Final_unseen_Result.xlsx"

df_encoded.to_excel(file_name)
